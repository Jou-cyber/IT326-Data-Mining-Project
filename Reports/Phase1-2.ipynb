# %%
import pandas as pd
import os

# The previous attempt to load the CSV resulted in a FileNotFoundError.
# This means the file '/content/Dataset/Raw_dataset.csv' could not be found at the specified location.
# Please ensure the dataset file is uploaded and the path is correct.

# To help locate your file, here is a list of files in the '/content/' directory:
print("--- Files in /content/ ---")
for root, dirs, files in os.walk('/content'):
    level = root.replace('/content', '').count(os.sep)
    indent = ' ' * 4 * (level)
    print(f'{indent}{os.path.basename(root)}/')
    subindent = ' ' * 4 * (level + 1)
    for f in files:
        print(f'{subindent}{f}')
print("--------------------------")

# Once you've confirmed the file path, uncomment the line below and update the path if necessary.
# df = pd.read_csv("/content/Dataset/Raw_dataset.csv")
# df.head()

# As the file is not found, df is not defined yet.
# Out:
# --- Files in /content/ ---
# content/
#     .config/
#         active_config
#         hidden_gcloud_config_universe_descriptor_data_cache_configs.db
#         .last_survey_prompt.yaml
#         default_configs.db
#         gce
#         .last_update_check.json
#         .last_opt_in_prompt.yaml
#         config_sentinel
#         logs/
#             2026.01.16/
#                 14.24.28.646070.log
#                 14.24.13.071214.log
#                 14.23.31.981136.log
#                 14.24.29.392089.log
#                 14.24.18.954466.log
#                 14.24.03.314209.log
#         configurations/
#             config_default
#     .ipynb_checkpoints/
#     Dataset/
#         anscombe.json
#         mnist_train_small.csv
#         README.md
#         california_housing_train.csv
#         california_housing_test.csv
#         mnist_test.csv
#         Raw_dataset.csv
#         .ipynb_checkpoints/
# --------------------------

# %%
import pandas as pd

df = pd.read_csv("/content/Dataset/Raw_dataset.csv")
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       4751   73       0          0               2  22.927749        0
# 1       4752   89       0          0               0  26.827681        0
# 2       4753   73       0          3               1  17.795882        0
# 3       4754   74       1          0               1  33.800817        1
# 4       4755   89       0          0               0  20.716974        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  ...  MemoryComplaints  \
# 0           13.297218          6.327112     1.347214  ...                 0
# 1            4.542524          7.619885     0.518767  ...                 0
# 2           19.555085          7.844988     1.826335  ...                 0
# 3           12.209266          8.428001     7.435604  ...                 0
# 4           18.454356          6.310461     0.795498  ...                 0
#
#    BehavioralProblems       ADL  Confusion  Disorientation  \
# ...

# %%
df.shape
# Out:
# (2149, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PatientID                  2149 non-null   int64
#  1   Age                        2149 non-null   int64
#  2   Gender                     2149 non-null   int64
#  3   Ethnicity                  2149 non-null   int64
#  4   EducationLevel             2149 non-null   int64
#  5   BMI                        2149 non-null   float64
#  6   Smoking                    2149 non-null   int64
#  7   AlcoholConsumption         2149 non-null   float64
#  8   PhysicalActivity           2149 non-null   float64
#  9   DietQuality                2149 non-null   float64
#  10  SleepQuality               2149 non-null   float64
#  11  FamilyHistoryAlzheimers    2149 non-null   int64
#  12  CardiovascularDisease      2149 non-null   int64
# ...

# %%
df.describe()
# Out:
#          PatientID          Age       Gender    Ethnicity  EducationLevel  \
# count  2149.000000  2149.000000  2149.000000  2149.000000     2149.000000
# mean   5825.000000    74.908795     0.506282     0.697534        1.286645
# std     620.507185     8.990221     0.500077     0.996128        0.904527
# min    4751.000000    60.000000     0.000000     0.000000        0.000000
# 25%    5288.000000    67.000000     0.000000     0.000000        1.000000
# 50%    5825.000000    75.000000     1.000000     0.000000        1.000000
# 75%    6362.000000    83.000000     1.000000     1.000000        2.000000
# max    6899.000000    90.000000     1.000000     3.000000        3.000000
#
#                BMI      Smoking  AlcoholConsumption  PhysicalActivity  \
# count  2149.000000  2149.000000         2149.000000       2149.000000
# mean     27.655697     0.288506           10.039442          4.920202
# std       7.217438     0.453173            5.757910          2.857191
# ...

# %%
df['Forgetfulness'].value_counts()
# Out:
# Forgetfulness
# 0    1501
# 1     648
# Name: count, dtype: int64

# %% [markdown]
# ## Dataset Description
# The dataset contains 2149 instances and 35 attributes.
# The attributes include demographic information, lifestyle factors, medical history, clinical measurements, and cognitive assessments.
#
# ## Class Label
# The class label used in this study is Forgetfulness, which indicates the presence or absence of memory-related issues.
